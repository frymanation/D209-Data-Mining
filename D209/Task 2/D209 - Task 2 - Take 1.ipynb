# %% [markdown]
# <h2>D209 - Data Mining - TASK 2: PREDICTIVE ANALYSIS</h2>
#
# Jonathon "Jon” Fryman<br>
# Data Analytics 01/01/2022<br>
# Student ID 000974544<br>
# Program Mentor: Lea Yoakem<br>
# C: 419-206-6989 (ET)<br>
# jfryma1@wgu.edu<br>

# %% [markdown]
# <h3>Part I: Research Question</h3>

# %% [markdown]
# <h3>A.  Describe the purpose of this data mining report by doing the following:</h3>

# %% [markdown]
# <h3>A1.  Propose one question relevant to a real-world organizational situation that you will answer using one of the following prediction methods:</h3>
#
# Can a customer's `MonthlyCharge` be derived from the services they reflect enrolled in using Random Forest Regression?

# %% [markdown]
# <h3>A2. Define one goal of the data analysis.</h3>
# Using the existing services listed as datapoints within the cleaned dataset, the goal is to approximate with a high degree of certainty what a customer's expected MonthlyCharge would be when factoring only their enrollment status in the included services within the dataset.

# %% [markdown]
# <h3>Part II: Method Justification</h3>

# %% [markdown]
# <h3>B.  Explain the reasons for your chosen prediction method from part A1 by doing the following:</h3>

# %% [markdown]
# <h3>B1.  Explain how the prediction method you chose analyzes the selected data set. Include expected outcomes.</h3>
#
# Per GeeksforGeeks(2022):
#
# Random Forest is an ensemble technique capable of performing both regression and classification tasks with the use of multiple decision trees and a technique called Bootstrap and Aggregation, commonly known as bagging. The basic idea behind this is to combine multiple decision trees in determining the final output rather than relying on individual decision trees.

# %% [markdown]
# <h3>B2.  Summarize one assumption of the chosen prediction method.</h3>
#
# Per Towards Data Science(2019):
#
# In Decision Tree as we have no probabilistic model, but just binary split, we don’t need to make any assumption at all. That was about Decision Tree, but it also applies for Random Forest. The difference is that for Random Forest we use Bootstrap Aggregation. It has no model underneath, and the only assumption that it relies is that sampling is representative. But this is usually a common assumption.

# %% [markdown]
# <h3>B3.  List the packages or libraries you have chosen for Python or R, and justify how each item on the list supports the analysis.</h3>
#
# The following Python libraries and packages will be utilized throughout the included analysis:
#
# <ul>
#     <li><strong>Pandas</strong> - A fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language</li>
#     <li><strong>Numpy</strong> - Offers comprehensive mathematical functions, random number generators, linear algebra routines</li>
#     <li><strong>Matplotlib</strong> - A comprehensive library for creating static, animated, and interactive visualizations</li>
#     <li><strong>scikit-learn</strong> - Simple and efficient tools for predictive data analysis</li>
#         <ul>
#             <li><strong>Metrics</strong> - Implements several loss, score, and utility functions to measure classification performance</li>
#                 <ul>
#                     <li><strong>mean_squared_error</strong> - Calculates mean squared error regression loss</li>
#                     <li><strong>accuracy_score</strong> - In multilabel classification, this function computes subset accuracy: the set of labels predicted for a sample must exactly match the corresponding set of labels in y_true.
# </li>
#                     <li><strong>roc_auc_score</strong> - Computes area under the receiver operating characteristic curve (ROC AUC) from prediction scores</li>
#                     <li><strong>classification_report</strong> - Builds a text report showing the main classification metrics.</li>
#                 </ul>
#             <li><strong>Ensemble</strong> - Includes two averaging algorithms based on randomized decision trees</li>
#                 <ul>
#                     <li><strong>RandomForestRegressor</strong> - A meta estimator that fits a number of classifying decision trees on various sub-samples of the dataset and uses averaging to improve the predictive accuracy and control over-fitting.</li>
#                     <li><strong>RandomForestClassifier</strong> - A meta estimator that fits a number of decision tree classifiers on various sub-samples of the dataset and uses averaging to improve the predictive accuracy and control over-fitting.</li>
#                 </ul>
#             <li><strong>Model_selection</strong></li>
#                 <ul>
#                     <li><strong>train_test_split</strong> - Split arrays or matrices into random train and test subsets.</li>
#                     <li><strong>GridSearchCV</strong> - Exhaustive search over specified parameter values for an estimator.</li>
#                 </ul>
#             <li><strong>Preprocessing</strong> - Provides several common utility functions and transformer classes to change raw feature vectors into a representation that is more suitable for the downstream estimators.
# </li>
#                 <ul>
#                     <li><strong>MinMaxScaler</strong> - Transform features by scaling each feature to a given range. This estimator scales and translates each feature individually such that it is in the given range on the training set, e.g. between zero and one.</li>
#                     <li><strong>LabelEncoder</strong> - Encodes target labels with value between 0 and n_classes-1.
#
# </li>
#                     <li><strong>OneHotEncoder</strong> - Encode categorical integer features using a one-hot aka one-of-K scheme. The input to this transformer should be a matrix of integers, denoting the values taken on by categorical (discrete) features. The output will be a sparse matrix where each column corresponds to one possible value of one feature. It is assumed that input features take on values in the range [0, n_values).</li>
#                     <li><strong>StandardScaler</strong> - Standardizes features by removing the mean and scaling to unit variance.</li>
#                 </ul>
#         </ul>
#
# </ul>

# %%
# importing required libraries and packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error as MSE, accuracy_score, roc_auc_score, classification_report
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor, AdaBoostClassifier, BaggingClassifier, GradientBoostingRegressor, RandomForestClassifier
from sklearn.preprocessing import MinMaxScaler, LabelEncoder, OneHotEncoder, StandardScaler

# %% [markdown]
# <h3>Part III: Data Preparation</h3>

# %% [markdown]
# <h3>C.  Perform data preparation for the chosen data set by doing the following:</h3>

# %% [markdown]
# <h3>C1.  Describe one data preprocessing goal relevant to the prediction method from part A1.</h3>
#
# Due to Random Forest being considered an "off-the-shelf" method, the type of preprocessing to be completed for this model will consist of removing unneeded columns from the dataset prior to creating dummy variables. The data will also be reviewed for any missing values or noticably egregious outliers in numerical data. An example of an outlier considered "egregious" would be customers that have a Population reflecting as 0.

# %% [markdown]
# <h3>C2.  Identify the initial data set variables that you will use to perform the analysis for the prediction question from part A1, and group each variable as continuous or categorical. </h3>
#
# The following is the collection of variables used for the included analysis.
#
# <h4>All Variables</h4>
# <ul>
#     <li>MonthlyCharge</li>
#     <li>Port_modem</li>
#     <li>Phone</li>
#     <li>Multiple</li>
#     <li>OnlineSecurity</li>
#     <li>OnlineBackup</li>
#     <li>DeviceProtection</li>
#     <li>TechSupport</li>
#     <li>StreamingTV</li>
#     <li>StreamingMovies</li>
#
# </ul>
# <h4>Numeric</h4>
# <ul>
#     <li>MonthlyCharge</li>
# </ul>
#
# <h4>Categorical</h4>
# <ul>
#     <li>Port_modem</li>
#     <li>Tablet</li>
#     <li>InternetService</li>
#     <li>Phone</li>
#     <li>Multiple</li>
#     <li>OnlineSecurity</li>
#     <li>OnlineBackup</li>
#     <li>DeviceProtection</li>
#     <li>TechSupport</li>
#     <li>StreamingTV</li>
#     <li>StreamingMovies</li>
#
# </ul>

# %% [markdown]
# <h3>C3.  Explain the steps used to prepare the data for the analysis. Identify the code segment for each step.</h3>
#
# The primary steps performed prior to analysis consisted of the following items:
#
# <ul>
#     <li>Reading in the csv file using Pandas</li>
#     <li>The columns named Item1-Item8 were renamed to better align with the variable's description</li>
#     <li>Confirmed the dataset did not contain any null or missing values</li>
#     <li>Corrected population values for records representing a 0 population value</li>
#     <li>Created a list containing the variables to be included for analysis with the model</li>
#     <li>Created dummy variables to convert categorical variables to numeric </li>
#     <li>Renamed dummy variables back to original variable name in numeric form</li>
# </ul>
#
# This steps can be seen in the cells below with annotation identifying with cell performs which step included in the list above.

# %%
# importing churn csv as pandas dataframe
df = pd.read_csv('churn_clean.csv')

# Updating column names to reflect title
df.rename(columns = {'Item1':'TimelyResponse',
                    'Item2':'TimelyFixes',
                    'Item3':'TimelyReplacements',
                    'Item4':'Reliability',
                    'Item5':'Options',
                    'Item6':'RespectfulResponse',
                    'Item7':'CourteousExchange',
                    'Item8':'EvidenceActiveListening'}, inplace=True)

# %%
# Counting null values for all columns
df.isnull().any()==True
# Out:
# CaseOrder                  False
# Customer_id                False
# Interaction                False
# UID                        False
# City                       False
# State                      False
# County                     False
# Zip                        False
# Lat                        False
# Lng                        False
# Population                 False
# Area                       False
# TimeZone                   False
# Job                        False
# Children                   False
# Age                        False
# Income                     False
# Marital                    False
# Gender                     False
# Churn                      False
# Outage_sec_perweek         False
# Email                      False
# Contacts                   False
# Yearly_equip_failure       False
# Techie                     False
# Contract                   False
# Port_modem                 False
# Tablet                     False
# InternetService            False
# Phone                      False
# Multiple                   False
# OnlineSecurity             False
# OnlineBackup               False
# DeviceProtection           False
# TechSupport                False
# StreamingTV                False
# StreamingMovies            False
# PaperlessBilling           False
# PaymentMethod              False
# Tenure                     False
# MonthlyCharge              False
# Bandwidth_GB_Year          False
# TimelyResponse             False
# TimelyFixes                False
# TimelyReplacements         False
# Reliability                False
# Options                    False
# RespectfulResponse         False
# CourteousExchange          False
# EvidenceActiveListening    False
# dtype: bool

# %%
# confirming if any values are missing or null
df.isna().any()==True
# Out:
# CaseOrder                  False
# Customer_id                False
# Interaction                False
# UID                        False
# City                       False
# State                      False
# County                     False
# Zip                        False
# Lat                        False
# Lng                        False
# Population                 False
# Area                       False
# TimeZone                   False
# Job                        False
# Children                   False
# Age                        False
# Income                     False
# Marital                    False
# Gender                     False
# Churn                      False
# Outage_sec_perweek         False
# Email                      False
# Contacts                   False
# Yearly_equip_failure       False
# Techie                     False
# Contract                   False
# Port_modem                 False
# Tablet                     False
# InternetService            False
# Phone                      False
# Multiple                   False
# OnlineSecurity             False
# OnlineBackup               False
# DeviceProtection           False
# TechSupport                False
# StreamingTV                False
# StreamingMovies            False
# PaperlessBilling           False
# PaymentMethod              False
# Tenure                     False
# MonthlyCharge              False
# Bandwidth_GB_Year          False
# TimelyResponse             False
# TimelyFixes                False
# TimelyReplacements         False
# Reliability                False
# Options                    False
# RespectfulResponse         False
# CourteousExchange          False
# EvidenceActiveListening    False
# dtype: bool

# %%
# Summary Statistics for all numerical variables contained in initial DataSet
df.describe()
# Out:
#          CaseOrder           Zip           Lat           Lng     Population  \
# count  10000.00000  10000.000000  10000.000000  10000.000000   10000.000000
# mean    5000.50000  49153.319600     38.757567    -90.782536    9756.562400
# std     2886.89568  27532.196108      5.437389     15.156142   14432.698671
# min        1.00000    601.000000     17.966120   -171.688150       0.000000
# 25%     2500.75000  26292.500000     35.341827    -97.082812     738.000000
# 50%     5000.50000  48869.500000     39.395800    -87.918800    2910.500000
# 75%     7500.25000  71866.500000     42.106908    -80.088745   13168.000000
# max    10000.00000  99929.000000     70.640660    -65.667850  111850.000000
#
#          Children           Age         Income  Outage_sec_perweek  \
# count  10000.0000  10000.000000   10000.000000        10000.000000
# mean       2.0877     53.078400   39806.926771           10.001848
# std        2.1472     20.698882   28199.916702            2.976019
# min        0.0000     18.000000     348.670000            0.099747
# 25%        0.0000     35.000000   19224.717500            8.018214
# 50%        1.0000     53.000000   33170.605000           10.018560
# 75%        3.0000     71.000000   53246.170000           11.969485
# max       10.0000     89.000000  258900.700000           21.207230
#
#               Email  ...  MonthlyCharge  Bandwidth_GB_Year  TimelyResponse  \
# count  10000.000000  ...   10000.000000       10000.000000    10000.000000
# mean      12.016000  ...     172.624816        3392.341550        3.490800
# std        3.025898  ...      42.943094        2185.294852        1.037797
# min        1.000000  ...      79.978860         155.506715        1.000000
# 25%       10.000000  ...     139.979239        1236.470827        3.000000
# 50%       12.000000  ...     167.484700        3279.536903        3.000000
# 75%       14.000000  ...     200.734725        5586.141369        4.000000
# max       23.000000  ...     290.160419        7158.981530        7.000000
#
#         TimelyFixes  TimelyReplacements   Reliability       Options  \
# count  10000.000000        10000.000000  10000.000000  10000.000000
# mean       3.505100            3.487000      3.497500      3.492900
# std        1.034641            1.027977      1.025816      1.024819
# min        1.000000            1.000000      1.000000      1.000000
# 25%        3.000000            3.000000      3.000000      3.000000
# 50%        4.000000            3.000000      3.000000      3.000000
# 75%        4.000000            4.000000      4.000000      4.000000
# max        7.000000            8.000000      7.000000      7.000000
#
#        RespectfulResponse  CourteousExchange  EvidenceActiveListening
# count        10000.000000       10000.000000             10000.000000
# mean             3.497300           3.509500                 3.495600
# std              1.033586           1.028502                 1.028633
# min              1.000000           1.000000                 1.000000
# 25%              3.000000           3.000000                 3.000000
# 50%              3.000000           4.000000                 3.000000
# 75%              4.000000           4.000000                 4.000000
# max              8.000000           7.000000                 8.000000
#
# [8 rows x 23 columns]

# %%
# creating list of unique areas
a = df['Area'].unique()

# creating empty area dictionary
ad = {}

# Creating dictionary associating area with median population
for i in a:
    ad[i] = df.loc[df['Area'] == i]['Population'].mean()
    
# assign mean population for area to records with 0 for population value
for key, value in ad.items():
    df.loc[(df['Population'] == 0) & (df['Area'] == key), 'Population'] = value

# %%
# summary statistics for initial DataFrame
df.describe()
# Out:
#          CaseOrder           Zip           Lat           Lng     Population  \
# count  10000.00000  10000.000000  10000.000000  10000.000000   10000.000000
# mean    5000.50000  49153.319600     38.757567    -90.782536    9851.073089
# std     2886.89568  27532.196108      5.437389     15.156142   14400.373732
# min        1.00000    601.000000     17.966120   -171.688150       2.000000
# 25%     2500.75000  26292.500000     35.341827    -97.082812     782.000000
# 50%     5000.50000  48869.500000     39.395800    -87.918800    3064.000000
# 75%     7500.25000  71866.500000     42.106908    -80.088745   13168.000000
# max    10000.00000  99929.000000     70.640660    -65.667850  111850.000000
#
#          Children           Age         Income  Outage_sec_perweek  \
# count  10000.0000  10000.000000   10000.000000        10000.000000
# mean       2.0877     53.078400   39806.926771           10.001848
# std        2.1472     20.698882   28199.916702            2.976019
# min        0.0000     18.000000     348.670000            0.099747
# 25%        0.0000     35.000000   19224.717500            8.018214
# 50%        1.0000     53.000000   33170.605000           10.018560
# 75%        3.0000     71.000000   53246.170000           11.969485
# max       10.0000     89.000000  258900.700000           21.207230
#
#               Email  ...  MonthlyCharge  Bandwidth_GB_Year  TimelyResponse  \
# count  10000.000000  ...   10000.000000       10000.000000    10000.000000
# mean      12.016000  ...     172.624816        3392.341550        3.490800
# std        3.025898  ...      42.943094        2185.294852        1.037797
# min        1.000000  ...      79.978860         155.506715        1.000000
# 25%       10.000000  ...     139.979239        1236.470827        3.000000
# 50%       12.000000  ...     167.484700        3279.536903        3.000000
# 75%       14.000000  ...     200.734725        5586.141369        4.000000
# max       23.000000  ...     290.160419        7158.981530        7.000000
#
#         TimelyFixes  TimelyReplacements   Reliability       Options  \
# count  10000.000000        10000.000000  10000.000000  10000.000000
# mean       3.505100            3.487000      3.497500      3.492900
# std        1.034641            1.027977      1.025816      1.024819
# min        1.000000            1.000000      1.000000      1.000000
# 25%        3.000000            3.000000      3.000000      3.000000
# 50%        4.000000            3.000000      3.000000      3.000000
# 75%        4.000000            4.000000      4.000000      4.000000
# max        7.000000            8.000000      7.000000      7.000000
#
#        RespectfulResponse  CourteousExchange  EvidenceActiveListening
# count        10000.000000       10000.000000             10000.000000
# mean             3.497300           3.509500                 3.495600
# std              1.033586           1.028502                 1.028633
# min              1.000000           1.000000                 1.000000
# 25%              3.000000           3.000000                 3.000000
# 50%              3.000000           4.000000                 3.000000
# 75%              4.000000           4.000000                 4.000000
# max              8.000000           7.000000                 8.000000
#
# [8 rows x 23 columns]

# %%
# seperating features that will be used in model
features = ['MonthlyCharge', 'Port_modem', 'Tablet', 'Phone',
 'Multiple', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies']

# %%
# creating dataframe containing updated variable list
df1 = df[features]

# generating list of all columns in new dataframe
list(df1.columns)
# Out:
# ['MonthlyCharge',
#  'Port_modem',
#  'Tablet',
#  'Phone',
#  'Multiple',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies']

# %%
# Creating dummy variables
df1 = pd.get_dummies(df1, drop_first = True)
df1.head(2)
# Out:
#    MonthlyCharge  Port_modem_Yes  Tablet_Yes  Phone_Yes  Multiple_Yes  \
# 0     172.455519               1           1          1             0
# 1     242.632554               0           1          1             1
#
#    OnlineSecurity_Yes  OnlineBackup_Yes  DeviceProtection_Yes  \
# 0                   1                 1                     0
# 1                   1                 0                     0
#
#    TechSupport_Yes  StreamingTV_Yes  StreamingMovies_Yes
# 0                0                0                    1
# 1                0                1                    1

# %%
# Listing all current columns in Dataframe containing dummy variables
list(df1.columns)
# Out:
# ['MonthlyCharge',
#  'Port_modem_Yes',
#  'Tablet_Yes',
#  'Phone_Yes',
#  'Multiple_Yes',
#  'OnlineSecurity_Yes',
#  'OnlineBackup_Yes',
#  'DeviceProtection_Yes',
#  'TechSupport_Yes',
#  'StreamingTV_Yes',
#  'StreamingMovies_Yes']

# %%
# Updating column names after converting to dummy variable value
df1.rename(columns = {'Port_modem_Yes':'Port_modem',
 'Tablet_Yes':'Tablet',
 'Phone_Yes':'Phone',
 'Multiple_Yes':'Multiple',
 'OnlineSecurity_Yes':'OnlineSecurity',
 'OnlineBackup_Yes':'OnlineBackup',
 'DeviceProtection_Yes':'DeviceProtection',
 'TechSupport_Yes':'TechSupport',
 'StreamingTV_Yes':'StreamingTV',
 'StreamingMovies_Yes':'StreamingMovies'}, inplace=True)

# %%
# Updated feature list for training without dependent variable inclusion
features1 = [
 'Port_modem',
 'Tablet',
 'Phone',
 'Multiple',
 'OnlineSecurity',
 'OnlineBackup',
 'DeviceProtection',
 'TechSupport',
 'StreamingTV',
 'StreamingMovies']

# %% [markdown]
# <h3>C4.  Provide a copy of the cleaned data set.</h3>

# %%
# Exporting full cleaned dataframe to csv
df.to_csv('df.csv', index=False)

# Exporting full cleaned dataframe with dummies to csv
df1.to_csv('df1.csv', index=False)

# %% [markdown]
# <h3>Part IV.  Analysis</h3>

# %% [markdown]
# <h3>D.  Perform the data analysis and report on the results by doing the following:</h3>

# %% [markdown]
# <h3>D1.  Split the data into training and test data sets and provide the file(s).</h3>
#
# The following cells of annotated code contain the steps to separate the selected features to use for analysis, followed by creating train test data using the sklearn.model_selection train_test_split package for seperation.
#
# Files containing the seperated datasets have been exported for review as shown in the code below.

# %%
# Seperating variables for training/testing
X = df1[features1]
y = df1['MonthlyCharge']

# %%
# Creating train test split for model
X_train,  X_test,y_train, y_test = train_test_split(X, y, test_size=.3, random_state=42)

# %%
# outputting training/testing data to csv files
X_train.to_csv('X_train.csv', index=False)
y_train.to_csv('y_train.csv', index=False)
X_test.to_csv('X_test.csv', index=False)
y_test.to_csv('y_test.csv', index=False)

# %% [markdown]
# <h3>D2.  Describe the analysis technique you used to appropriately analyze the data. Include screenshots of the intermediate calculations you performed..</h3>

# %%
forest = RandomForestRegressor(n_estimators=50, random_state=24)

# sc = StandardScaler()

# X_train = sc.fit_transform(X_train.astype(np.float))
# X_test = sc.fit_transform(X_test.astype(np.float))


forest.fit(X_train, y_train.values.ravel())
# Out:
# RandomForestRegressor(n_estimators=50, random_state=24)

# %%
y_train_pred = forest.predict(X_train)
y_test_pred = forest.predict(X_test)
y_train_pred
# Out:
# array([243.21244364, 147.03129316, 139.81698583, ..., 120.58082488,
#        136.72503556, 155.37345812])

# %% [markdown]
# <h3>D3.  Provide the code used to perform the prediction analysis from part D2.</h3>

# %% [markdown]
# <h3>Part V: Data Summary and Implications</h3>

# %% [markdown]
# <h3>E.  Summarize your data analysis by doing the following:</h3>

# %% [markdown]
# <h3>E1.  Explain the accuracy and the mean squared error (MSE) of your prediction model.</h3>
#
# The provided prediction model reflects an accuracy score of 92% on the training data and 90% on the test data. Overall, it is a highly accuract model that can generally predict a customer's MonthlyCharge with a high degree of certainty.
#
# The models MSE was 187.27 and the RMSE 13.69. The calculations of these value have been included below within the annotated code.

# %%
# printing model score for training and test data
print('The Random Forest Regressor Score on the training data is: ', forest.score(X_train, y_train))
print('The Random Forest Regressor Score on the test data is: ', forest.score(X_test, y_test))

# Calculating MSE and RMSE of model
prediction = forest.predict(X_test)
mse = MSE(y_test, prediction)
rmse = mse**.5
print('The models MSE is: ', mse)
print('The models RMSE is: ',rmse)
# Out:
# The Random Forest Regressor Score on the training data is:  0.9167129050777115
# The Random Forest Regressor Score on the test data is:  0.9002703562302603
# The models MSE is:  187.2723934522343
# The models RMSE is:  13.684750397878446

# %% [markdown]
# <h3>E2.  Discuss the results and implications of your prediction analysis.</h3>
#
# The model reflects a good accuracy in predicting the Monthly charge of customers using the initially selected variables. This base model provides an excellent starting point in attempting to assess customer related charges.

# %% [markdown]
# <h3>E3.  Discuss one limitation of your data analysis.</h3>
#
# The provided dataset does not include context regarding if there are other service offerings beyond what has been included. Additional service offerings may decrease the accuracy of the current model depending on quantity and cost of each service.

# %% [markdown]
# <h3>E4.  Recommend a course of action for the real-world organizational situation from part A1 based on your results and implications discussed in part E2.</h3>

# %% [markdown]
# <h3>Part VI: Demonstration</h3>

# %% [markdown]
# <h3>F: PANOPTO</h3>

# %% [markdown]
# <h3>G: WEB SOURCES</h3>
# <ul>
#     <li>Koehrsen, W. (2018, January 17). Random Forest in python. Medium. Retrieved July 5, 2022, from https://towardsdatascience.com/random-forest-in-python-24d0893d51c0 </li>
# </ul>

# %% [markdown]
# <h3>H: SOURCES</h3>
# <ul>
#     <li>dearC. (2019, August 26). All the annoying assumptions. Medium. Retrieved July 5, 2022, from https://towardsdatascience.com/all-the-annoying-assumptions-31b55df246c3 </li>
#     <li>Avik_Dutta@Avik_Dutta. (2022, May 16). Random Forest regression in python. GeeksforGeeks. Retrieved July 5, 2022, from https://www.geeksforgeeks.org/random-forest-regression-in-python/ </li>
#     <li>Learn: Machine learning in python - scikit-learn 0.16.1 documentation. scikit. (n.d.). Retrieved July 8, 2022, from https://scikit-learn.org/ </li>
# </ul>

# %% [markdown]
# <h3></h3>

# %% [markdown]
# <h3></h3>

# %% [markdown]
# <h3></h3>

# %% [markdown]
# <h3></h3>
